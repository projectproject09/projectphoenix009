# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator  
from nltk.corpus import stopwords
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# df = pd.read_csv('datasentimen.csv')
# df.head()
df = pd.read_csv('riviewcapstone.csv')
df.head()

# %%
fig = px.histogram(df, x="score")
fig.update_traces(marker_color="turquoise",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Product Score')
fig.show()

# %%
stopwords = set(STOPWORDS)
stopwords.update(["br", "href"])
textt = " ".join(review for review in df.content)
#wordcloud = WordCloud(stopwords=stopwords).generate(textt)plt.imshow(wordcloud, interpolation='bilinear')
wordcloud = WordCloud(stopwords=stopwords).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud09.png')
plt.show()

# %%
df['sentiment'] = df['score'].apply(lambda rating : +1 if rating > 3 else -1)

# %%
# df['sentiment'] = df['score'].apply(lambda
# if 51<5:
#   print("False, statement skipped")
# elif 0<5:
#   print("true, block executed")
# elif 0<3:
#   print("true, but block will not execute")
# else:
#   print("If all fails.")

# %%
#split df positive and negative sentiment:
positive = df[df['sentiment'] == 1]
negative = df[df['sentiment'] == -1]

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  52c93a6c-a0a1-47c2-93b0-d0a5aa1e43a9  A Google user
# 1  52c93a6c-a0a1-47c2-93b0-d0a5aa1e43a9  A Google user
# 2  5d8ac625-821f-4c6d-bd17-bd4852fdfa57  A Google user
# 3  5d8ac625-821f-4c6d-bd17-bd4852fdfa57  A Google user
# 4  f2935c81-2b90-448f-a8a2-2ab42e9d59b5  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                   Thankyouuuuuuiuu      5              1
# 1                                   Thankyouuuuuuiuu      5              1
# 2  Detailed explanations of both the exercises an...      5             19
# ...

# %%
df['sentimentt'] = df['sentiment'].replace({-1 : 'negative'})
df['sentimentt'] = df['sentimentt'].replace({1 : 'positive'})

# %%
#df.drop(["userImage", "at", "thumbsUpCount", "reviewCreatedVersion",	"replyContent",	"repliedAt"], axis=1)

# %%
dfnew = pd.DataFrame(df)
dfnew
# Out:
#                                  reviewId           userName  \
# 0    52c93a6c-a0a1-47c2-93b0-d0a5aa1e43a9      A Google user
# 1    52c93a6c-a0a1-47c2-93b0-d0a5aa1e43a9      A Google user
# 2    5d8ac625-821f-4c6d-bd17-bd4852fdfa57      A Google user
# 3    5d8ac625-821f-4c6d-bd17-bd4852fdfa57      A Google user
# 4    f2935c81-2b90-448f-a8a2-2ab42e9d59b5      A Google user
# ..                                    ...                ...
# 373  6fae7299-e4aa-420e-99ad-e6fd5104a91a  Dr. Hassan Mohsin
# 374  34dfab3d-0d36-493f-9a21-3de33c17122b       Conan Hughes
# 375  34dfab3d-0d36-493f-9a21-3de33c17122b       Conan Hughes
# 376  ddd59262-fe14-4614-b34c-e3dfd1e94ffc  rosita capobianco
# 377  ddd59262-fe14-4614-b34c-e3dfd1e94ffc  rosita capobianco
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/EGemoI2N...
# 1    https://play-lh.googleusercontent.com/EGemoI2N...
# 2    https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
dfnew.to_csv("result.csv", index=False)
